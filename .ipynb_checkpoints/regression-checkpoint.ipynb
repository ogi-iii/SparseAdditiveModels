# %%
import numpy as np
import scipy
from scipy.interpolate import UnivariateSpline
import matplotlib.pylab as plt
# %matplotlib inline

# %%
x = np.linspace(-3, 3, 50)

# features
x1 = 10 + 4*np.sin(x)
x2 = np.random.randn(50)
x3 = 5 + 2*np.sin(x**2)
x4 = 2 + np.sin(2*x) + np.sin(x)

# target
y = 10 + 4*np.sin(2*x) + 2*np.sin(x**2) + np.random.randn(50)

plt.plot(x1, 'x')
plt.show()
plt.plot(x2, 'x')
plt.show()
plt.plot(x3, 'x')
plt.show()
plt.plot(x4, 'x')
plt.show()
plt.plot(y, 'ro')
plt.show()

# %%
# sample data
X = np.hstack([x1.reshape(-1,1), x2.reshape(-1,1), x3.reshape(-1,1), x4.reshape(-1,1)])

print(X.shape, y.shape)
# Out:
# (50, 4) (50,)

# %%
# param
lambda_ = 1
threshold = 0.01
max_iter = 1000

# init
f = np.zeros_like(X)
ave_y = np.mean(y)

# %%
j = 2

f_k = np.delete(np.copy(f), j, axis=1)

R_j = y - ave_y - np.sum(f_k, axis=1)

# %%
R_j.shape
# Out:
# (50,)
